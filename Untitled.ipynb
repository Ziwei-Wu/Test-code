# %%
import glob
from dynspec import Dynspec

# %%
dyn_files = sorted(glob.glob('combine.ar.ds'))

# %%
dyn = Dynspec(filename=dyn_files[0], process=False)
# Out:
# LOADING combine.ar.ds...
# ...LOADED in 1.91 seconds
#
# 	 OBSERVATION PROPERTIES
#
# filename:			combine.ar.ds
# MJD:				58479.050368
# Centre frequency (MHz):		119.04
# Bandwidth (MHz):		1.95
# Channel bandwidth (MHz):	0.00501
# Integration time (s):		6360.0
# Subintegration time (s):	10.0

# %%
dyn.plot_dyn()

# %%
dyn.default_processing()
dyn.plot_dyn()
# Out:
# dynspec.py:1313: RuntimeWarning: divide by zero encountered in log10
#   sec = 10*np.log10(sec)

# %%
dyn.plot_acf()
dyn.plot_sspec()

# %%
dyn.correct_band(time=True)
dyn.plot_dyn()
dyn.calc_sspec()
dyn.plot_sspec()

# %%
dyn.scale_dyn()
dyn.plot_dyn(lamsteps=True)
dyn.plot_sspec(lamsteps=True)
